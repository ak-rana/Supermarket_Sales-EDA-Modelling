# %% [markdown]
# # Assignment

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/akank/Downloads/Business analytics/supermarket_sales (1).csv")

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# # Question
#
# As always, do your EDA, find me insights. I want a good section going over this, what you find me, i don't know. At the end, your mention some actionable items for a business, that it can do to perform better.
#
# ![](https://media.giphy.com/media/ukwPlCmJ5RmlqvQCpA/giphy.gif)
#
#
# ### Modeling
# - Fit a Simple Linear Regression Model, that tries to predict the ```Rating``` column with the help of the ```Total``` Column. We only have to use these 2 columns, nothing more.
#     - What was the training accuracy.
#     - What was the testing accuracy.
#
#
# ---
#
#
# - Make a python function, that takes ```Total``` as an input, and predicts what the ```Rating``` will be using your newly trained model to assist you !!
# - Just to be clear, your function will take 1 float value as an input and return back a float value as an output.

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------
# ![gif](https://media1.giphy.com/media/34ROsTy8afSqFLQEgJ/giphy.gif)

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df['month'] = df['Date'].dt.month

# %%
plt.xlabel('Date')
plt.ylabel('Quantity')
plt.title('Sales Trend')

 
sns.lineplot(data=df, x="Date", y="Quantity")
# Out:
# <AxesSubplot:title={'center':'Sales Trend'}, xlabel='Date', ylabel='Quantity'>

# %% [markdown]
# This Visual representation tries to analyze the Sales Trend from the provided Data.
#
# To simplify the trend, Month figures have been taken from the Date column and simultaneously compared with the Quantity sold in a line graph.
#
# As anlyzing the sales trend could've given any seasonal patterns from the data; however, we do not see any such significant patterns to make the conclusions. Hence, no business related conclusions are drawn from this visualisation.
#
# ![gif](https://media.tenor.com/-DG_FI1T4K4AAAAM/i-expected-more-leonardo-da-vinci.gif)

# %%
from sklearn import preprocessing

# %%
#We're using encoder to transform the categorical column to integral values as so it'll be easy to visualize the same on the graphs/diagrams we'll be using further.

# %%
le = preprocessing.LabelEncoder()

# %%
col_list = ["Product line" ]

# %%
for i in col_list:
    df[i] = le.fit_transform(df[i])

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  Product line  \
# 0    750-67-8428      A     Yangon        Member  Female             3
# 1    226-31-3081      C  Naypyitaw        Normal  Female             0
# 2    631-41-3108      A     Yangon        Normal    Male             4
# 3    123-19-1176      A     Yangon        Member    Male             3
# 4    373-73-7910      A     Yangon        Normal    Male             5
# ..           ...    ...        ...           ...     ...           ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male             3
# 996  303-96-2227      B   Mandalay        Normal  Female             4
# 997  727-02-1313      A     Yangon        Member    Male             2
# 998  347-56-2442      A     Yangon        Normal    Male             4
# 999  849-09-3807      A     Yangon        Member  Female             1
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time      Payment  \
# ...

# %% [markdown]
# As we've transformed the values we'll now be using the name Product line 0,1,2,3,4,5 while presenting the data to the management rather than using the complete names.
# However, we understand that categorical names can altogether refer different conclusions/meanings from dataset, encoder has been used to just simplify the visual representation.

# %%
sns.displot(df, x="Product line", hue = "Quantity")
plt.title('Popular Products amongst Customers')
plt.show()

# %% [markdown]
# Here I've tried to represent the "Popular Products amongst the customers", by taking the Product Line and the Quantity as hue.
#
# Producr line 1 is seen to be in more demand amongst customers, it is the preferred line of products in the business.
#      Reasons can be:
#      Better market awareness of the product.
#      Quality of the product is preferred comparartive to its competitiors.
#      The Products comes under the category of necessity goods and have larger customer demand.
#
# How would this info help the business?
# This information can help the business make informed decisions about inventory management, product placement, and marketing strategies.
# For instance, the business can decide if to produce more products of line 1 and less less products from line 3 so that ndemands are matched and no surplus inventory gets accumulated which'll cost the business money, resp.

# %%
df.head(1)
# Out:
#     Invoice ID Branch    City Customer type  Gender  Product line  Unit price  \
# 0  750-67-8428      A  Yangon        Member  Female             3       74.69
#
#    Quantity   Tax 5%     Total       Date   Time  Payment    cogs  \
# 0         7  26.1415  548.9715 2019-01-05  13:08  Ewallet  522.83
#
#    gross margin percentage  gross income  Rating  month
# 0                 4.761905       26.1415     9.1      1

# %%
sns.countplot(x="City", hue = "Payment", data =df).set_title("City Wise Preferred Payment Channels") 
plt.show()

# %% [markdown]
# This data visualisation represents "City wise preferred paymnet channels"
# 1. Yangwon has E-wallet as the most preferred payment option and credit card as the least.
#         Customers may prefer payment channels that is easily accessible to them. For example, here customer does not have a credit card, they prefer to use a payment channel that accepts ewallet or cash. If a product is available through a payment channel that is not accessible to a large number of customers, it may affect the demand for that product.
#
# 2. Similary, for other cities too. Naypyitaw City has Cash as the preferred payment option. The business might want to conclude if the city prefers cash paymnet options it can be considered under sub-urban or rural area, as customer in rural areas may prefer more cash payments.Therefore, businesses may need to cater to different payment options in different areas to meet the demand.
# How would this info help the business?
# Preferred Cash payments, refer the socio-ecoomic status of that area. If there are more cash transactions happening, that means expensive or luxury products will not be in demand in such areas and the demand for necessity goods would be more. Hnece, the suppy chain of the business scould take that into consideration and cater to customer demands accordingly.

# %%
plt.xlabel('gross income')
plt.ylabel('Unit price')
plt.title('Corelation between Gross Income & Rating')

 
plt.scatter(df['Rating'],df['gross income'])

# %% [markdown]
# This data visualisation represents "Correlation between Rating and Gross Income"
# 1. The reason to take those variables into consideration is because, it was assumed (by me) that rating of a branch could effect the demand accordingly. A high rating would mean better customer segment, more loyal customers, more word of mouth, better customer awareness, hence, better demant, better income.
# 2. Suprisingly that's not the case, the rating has no correlation with the gross income in the business.
#
# ![gif](https://media.tenor.com/fpAaqMXTf7gAAAAC/better-ummeed-kiye-the-mirzapur.gif)

# %%
sns.countplot(y ='Product line', hue = "Gender", data = df).set_title("Gender Wise Product Preference")
# Out:
# Text(0.5, 1.0, 'Gender Wise Product Preference')

# %% [markdown]
# This data visualisation represents "Gender wise prefernce"
# 1. It is observed that the Product line 1,2,5 has more product demand amongst females, whereas product line 0,3,4 has more customer segment of males.
# 2. Hence, accordingly the business can use marketing tactics to promote products in customer segments they already have high demand in and target the ones tehy need to create more demand in. And make investing decisions accordingly.
#
# ![gif](https://media.tenor.com/fKZ4uAgXwJkAAAAC/special26-special-chabbis.gif)

# %% [markdown]
# # ----------------------------------------------------------------------------------------------------------
# ![gif](https://media4.giphy.com/media/2vnOC1o6v1BbPNJO5r/giphy.gif)

# %% [markdown]
# # Creating the Model

# %%
X = df['Total']
X.head()
# Out:
# 0    548.9715
# 1     80.2200
# 2    340.5255
# 3    489.0480
# 4    634.3785
# Name: Total, dtype: float64

# %%
y = df['Rating']
y.head()
# Out:
# 0    9.1
# 1    9.6
# 2    7.4
# 3    8.4
# 4    5.3
# Name: Rating, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.70,random_state=100)

# %%
X_train.shape
# Out:
# (700,)

# %%
X_train.values.reshape(-1,1)
# Out:
# array([[ 121.59  ],
#        [ 745.395 ],
#        [ 796.908 ],
#        [ 461.286 ],
#        [  77.805 ],
#        [ 309.3615],
#        [  40.53  ],
#        [ 931.035 ],
#        [ 551.124 ],
#        [ 216.6885],
#        [ 225.2775],
#        [  19.2465],
#        [ 610.491 ],
#        [  92.295 ],
#        [  66.8745],
#        [ 251.7165],
#        [  96.579 ],
#        [ 217.2555],
#        [  95.6655],
#        [ 192.843 ],
#        [ 451.0275],
#        [ 435.456 ],
#        [ 308.91  ],
#        [ 195.594 ],
#        [  88.368 ],
#        [ 494.76  ],
#        [ 728.112 ],
#        [ 223.0725],
#        [ 441.693 ],
#        [ 165.648 ],
#        [ 489.048 ],
#        [ 306.81  ],
#        [  80.955 ],
#        [  90.825 ],
#        [ 193.011 ],
#        [ 625.905 ],
#        [ 326.424 ],
#        [  72.933 ],
#        [ 408.7335],
#        [ 737.7615],
#        [ 783.3   ],
#        [ 261.198 ],
#        [ 176.925 ],
#        [ 197.925 ],
#        [ 888.615 ],
# ...

# %%
X_train.values.reshape(-1,1).shape
# Out:
# (700, 1)

# %%
X_train = X_train.values.reshape(-1,1)
X_test = X_test.values.reshape(-1,1)

# %% [markdown]
# # Train the Model

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict([[1050.0]])
# Out:
# array([6.67279472])

# %%
y_pred_test = lr.predict(X_test)

# %%
y_pred_test
# Out:
# array([6.87063806, 6.97933082, 7.03807075, 7.07113778, 6.99735045,
#        6.89479651, 6.99570641, 7.02376843, 6.72247219, 6.97359694,
#        6.95661395, 6.8343275 , 6.95568259, 6.9885512 , 6.79532817,
#        6.92081766, 6.99748003, 6.84206582, 6.99725326, 7.07283446,
#        6.89372343, 7.02757888, 6.83496325, 7.06528241, 7.03330871,
#        7.01404998, 7.03853238, 7.03173756, 6.94031125, 6.92424341,
#        6.99211058, 6.89823036, 7.06748931, 7.02027789, 7.04891897,
#        6.83979008, 7.02249694, 7.06322534, 6.9161609 , 6.98778587,
#        6.91565473, 6.89087268, 6.9017614 , 6.79463168, 7.01870674,
#        6.8722821 , 7.0446631 , 7.03334921, 7.03824083, 6.86402142,
#        6.94922792, 6.81472458, 6.92064758, 6.8835312 , 7.05381869,
#        6.75799313, 6.75559996, 7.04504374, 7.06217251, 6.77363983,
#        6.94232782, 7.0321263 , 6.92387087, 6.97006185, 6.85560281,
#        7.07206913, 6.96028266, 6.97592936, 6.83323013, 7.06676852,
# ...

# %%
y_test
# Out:
# 249    4.2
# 353    4.8
# 537    6.9
# 424    5.0
# 564    9.0
#       ...
# 193    5.7
# 838    5.8
# 974    8.2
# 203    8.7
# 425    7.0
# Name: Rating, Length: 300, dtype: float64

# %% [markdown]
# # Checking Test Accuracy

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
mean_squared_error(y_test,y_pred_test)
# Out:
# 3.0873236156944746

# %%
mse = mean_squared_error(y_test,y_pred_test)

# %%
r2_score(y_test,y_pred_test)
# Out:
# -0.005460338479640114

# %%
x_range = [i for i in range(len(y_test))]

# %%
plt.xlabel('Total')
plt.ylabel('Ratings')
plt.title('Prediction')

plt.plot(x_range,y_test)
plt.plot(x_range,y_pred_test)

plt.legend(["Real", "Predicted"])

# %% [markdown]
# # Checking the Train Accuracy

# %%
y_pred_train = lr.predict(X_train)

# %%
y_train
# Out:
# 420    7.5
# 278    5.7
# 218    8.7
# 363    7.2
# 850    9.2
#       ...
# 855    4.2
# 871    9.6
# 835    5.8
# 792    4.9
# 520    7.7
# Name: Rating, Length: 700, dtype: float64

# %%
mean_squared_error(y_train,y_pred_train)
# Out:
# 2.8883801757313763

# %%
mse = mean_squared_error(y_train,y_pred_train)

# %%
r2_score(y_train,y_pred_train)
# Out:
# 0.0031571343917367045

# %%
x_range = [i for i in range(len(y_train))]

# %%
plt.xlabel('Total')
plt.ylabel('Ratings')
plt.title('Prediction')

plt.plot(x_range,y_train)
plt.plot(x_range,y_pred_train)
 
plt.legend(["Real", "Predicted"])

# %% [markdown]
# Hence, there's no relation in the data for which we could predict outcomes for X & Y.

# %% [markdown]
# # ThankYou!
# ![gif](https://media.tenor.com/YG8C8C5gkQUAAAAM/happy-tears.gif)
